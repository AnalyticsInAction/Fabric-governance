# %% [markdown]
# # Difinity Code: Fabric Admin & Governance
# **Presentation Demo**
#
# This notebook demonstrates how to use `semantic-link-labs` to automate administrative tasks, audit security, and manage tenant settings in Microsoft Fabric.
#
# ### Prerequisites
# - **Library:** `semantic-link-labs` must be installed.
# - **Permissions:** Fabric Administrator role is required for most operations.
# - **Service Principal:** Required for the Graph API section (Client ID/Secret).
#
# > **Documentation:** [Semantic Link Labs Installation](https://semantic-link-labs.readthedocs.io/en/stable/)

# %%
# Install the required library
# %pip install semantic-link-labs
# Out:
# Collecting semantic-link-labs
#   Downloading semantic_link_labs-0.12.7-py3-none-any.whl.metadata (28 kB)
# Collecting semantic-link-sempy>=0.12.2 (from semantic-link-labs)
#   Downloading semantic_link_sempy-0.12.2-py3-none-any.whl.metadata (12 kB)
# Collecting anytree (from semantic-link-labs)
#   Downloading anytree-2.13.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting polib (from semantic-link-labs)
#   Downloading polib-1.2.0-py2.py3-none-any.whl.metadata (15 kB)
# Collecting jsonpath_ng (from semantic-link-labs)
#   Downloading jsonpath_ng-1.7.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: clr_loader>=0.2.5 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.12.2->semantic-link-labs) (0.2.7.post0)
# Collecting fabric-analytics-sdk==0.0.1 (from fabric-analytics-sdk[online-notebook]==0.0.1->semantic-link-sempy>=0.12.2->semantic-link-labs)
#   Downloading fabric_analytics_sdk-0.0.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: graphviz>=0.20.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.12.2->semantic-link-labs) (0.20.3)
# Requirement already satisfied: azure-storage-blob>=12.18.3 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.12.2->semantic-link-labs) (12.22.0)
# Requirement already satisfied: azure-core>=1.29.4 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.12.2->semantic-link-labs) (1.29.4)
# Requirement already satisfied: azure-keyvault-secrets>=4.7.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.12.2->semantic-link-labs) (4.7.0)
# Requirement already satisfied: azure-storage-file-datalake>=12.12.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.12.2->semantic-link-labs) (12.12.0)
# Requirement already satisfied: pyarrow>=12.0.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.12.2->semantic-link-labs) (17.0.0)
# Requirement already satisfied: pythonnet>=3.0.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.12.2->semantic-link-labs) (3.0.3)
# Requirement already satisfied: scikit_learn>=1.2.2 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.12.2->semantic-link-labs) (1.5.0)
# Requirement already satisfied: setuptools>=68.2.2 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.12.2->semantic-link-labs) (80.1.0)
# Requirement already satisfied: tqdm>=4.65.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.12.2->semantic-link-labs) (4.66.4)
# Requirement already satisfied: rich>=13.3.5 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.12.2->semantic-link-labs) (13.9.4)
# Requirement already satisfied: regex>=2023.8.8 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.12.2->semantic-link-labs) (2023.12.25)
# Requirement already satisfied: pandas>=1.5.3 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.12.2->semantic-link-labs) (2.1.4)
# Requirement already satisfied: pyjwt>=2.4.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.12.2->semantic-link-labs) (2.8.0)
# Requirement already satisfied: pyspark>=3.4.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.12.2->semantic-link-labs) (3.5.1.5.4.20240407)
# Requirement already satisfied: requests>=2.31.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.12.2->semantic-link-labs) (2.32.3)
# Requirement already satisfied: aiohttp>=3.8.6 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.12.2->semantic-link-labs) (3.11.11)
# Requirement already satisfied: IPython>=8.14.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.12.2->semantic-link-labs) (8.20.0)
# Requirement already satisfied: tenacity>=8.2.3 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.12.2->semantic-link-labs) (9.0.0)
# Requirement already satisfied: azure-identity in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from fabric-analytics-sdk==0.0.1->fabric-analytics-sdk[online-notebook]==0.0.1->semantic-link-sempy>=0.12.2->semantic-link-labs) (1.17.1)
# Collecting fabric-analytics-notebook-plugin (from fabric-analytics-sdk[online-notebook]==0.0.1->semantic-link-sempy>=0.12.2->semantic-link-labs)
#   Downloading fabric_analytics_notebook_plugin-0.0.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: ply in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from jsonpath_ng->semantic-link-labs) (3.11)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.12.2->semantic-link-labs) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.12.2->semantic-link-labs) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.12.2->semantic-link-labs) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.12.2->semantic-link-labs) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.12.2->semantic-link-labs) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.12.2->semantic-link-labs) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.12.2->semantic-link-labs) (1.20.0)
# Requirement already satisfied: six>=1.11.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from azure-core>=1.29.4->semantic-link-sempy>=0.12.2->semantic-link-labs) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from azure-core>=1.29.4->semantic-link-sempy>=0.12.2->semantic-link-labs) (4.13.2)
# Requirement already satisfied: azure-common~=1.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from azure-keyvault-secrets>=4.7.0->semantic-link-sempy>=0.12.2->semantic-link-labs) (1.1.28)
# Requirement already satisfied: isodate>=0.6.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from azure-keyvault-secrets>=4.7.0->semantic-link-sempy>=0.12.2->semantic-link-labs) (0.6.1)
# Requirement already satisfied: cryptography>=2.1.4 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from azure-storage-blob>=12.18.3->semantic-link-sempy>=0.12.2->semantic-link-labs) (44.0.3)
# Requirement already satisfied: cffi>=1.17 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from clr_loader>=0.2.5->semantic-link-sempy>=0.12.2->semantic-link-labs) (1.17.1)
# Requirement already satisfied: decorator in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.12.2->semantic-link-labs) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.12.2->semantic-link-labs) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.12.2->semantic-link-labs) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.12.2->semantic-link-labs) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.12.2->semantic-link-labs) (2.19.1)
# Requirement already satisfied: stack-data in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.12.2->semantic-link-labs) (0.6.3)
# Requirement already satisfied: traitlets>=5 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.12.2->semantic-link-labs) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.12.2->semantic-link-labs) (4.9.0)
# Requirement already satisfied: numpy<2,>=1.23.2 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from pandas>=1.5.3->semantic-link-sempy>=0.12.2->semantic-link-labs) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from pandas>=1.5.3->semantic-link-sempy>=0.12.2->semantic-link-labs) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from pandas>=1.5.3->semantic-link-sempy>=0.12.2->semantic-link-labs) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from pandas>=1.5.3->semantic-link-sempy>=0.12.2->semantic-link-labs) (2025.2)
# Requirement already satisfied: py4j==0.10.9.7 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from pyspark>=3.4.1->semantic-link-sempy>=0.12.2->semantic-link-labs) (0.10.9.7)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.12.2->semantic-link-labs) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.12.2->semantic-link-labs) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.12.2->semantic-link-labs) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.12.2->semantic-link-labs) (2024.7.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from rich>=13.3.5->semantic-link-sempy>=0.12.2->semantic-link-labs) (3.0.0)
# Requirement already satisfied: scipy>=1.6.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from scikit_learn>=1.2.2->semantic-link-sempy>=0.12.2->semantic-link-labs) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from scikit_learn>=1.2.2->semantic-link-sempy>=0.12.2->semantic-link-labs) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from scikit_learn>=1.2.2->semantic-link-sempy>=0.12.2->semantic-link-labs) (3.6.0)
# Requirement already satisfied: pycparser in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from cffi>=1.17->clr_loader>=0.2.5->semantic-link-sempy>=0.12.2->semantic-link-labs) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from jedi>=0.16->IPython>=8.14.0->semantic-link-sempy>=0.12.2->semantic-link-labs) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=13.3.5->semantic-link-sempy>=0.12.2->semantic-link-labs) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from pexpect>4.3->IPython>=8.14.0->semantic-link-sempy>=0.12.2->semantic-link-labs) (0.7.0)
# Requirement already satisfied: wcwidth in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython>=8.14.0->semantic-link-sempy>=0.12.2->semantic-link-labs) (0.2.13)
# Requirement already satisfied: msal>=1.24.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from azure-identity->fabric-analytics-sdk==0.0.1->fabric-analytics-sdk[online-notebook]==0.0.1->semantic-link-sempy>=0.12.2->semantic-link-labs) (1.32.3)
# Requirement already satisfied: msal-extensions>=0.3.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from azure-identity->fabric-analytics-sdk==0.0.1->fabric-analytics-sdk[online-notebook]==0.0.1->semantic-link-sempy>=0.12.2->semantic-link-labs) (1.3.1)
# Requirement already satisfied: psutil in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from fabric-analytics-notebook-plugin->fabric-analytics-sdk[online-notebook]==0.0.1->semantic-link-sempy>=0.12.2->semantic-link-labs) (7.0.0)
# Requirement already satisfied: synapseml-utils in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from fabric-analytics-notebook-plugin->fabric-analytics-sdk[online-notebook]==0.0.1->semantic-link-sempy>=0.12.2->semantic-link-labs) (1.1.3)
# INFO: pip is looking at multiple versions of fabric-analytics-notebook-plugin to determine which version is compatible with other requirements. This could take a while.
#   Downloading fabric_analytics_notebook_plugin-0.0.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: executing>=1.2.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy>=0.12.2->semantic-link-labs) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy>=0.12.2->semantic-link-labs) (3.0.0)
# Requirement already satisfied: pure_eval in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy>=0.12.2->semantic-link-labs) (0.2.3)
# Downloading semantic_link_labs-0.12.7-py3-none-any.whl (796 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 796.0/796.0 kB 31.2 MB/s eta 0:00:00
# Downloading semantic_link_sempy-0.12.2-py3-none-any.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 67.6 MB/s eta 0:00:00:00:01
# Downloading fabric_analytics_sdk-0.0.1-py3-none-any.whl (34 kB)
# Downloading anytree-2.13.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 3.0 MB/s eta 0:00:00
# Downloading jsonpath_ng-1.7.0-py3-none-any.whl (30 kB)
# Downloading polib-1.2.0-py2.py3-none-any.whl (20 kB)
# Downloading fabric_analytics_notebook_plugin-0.0.1-py3-none-any.whl (20 kB)
# Installing collected packages: polib, jsonpath_ng, anytree, fabric-analytics-sdk, fabric-analytics-notebook-plugin, semantic-link-sempy, semantic-link-labs
#   Attempting uninstall: semantic-link-sempy
#     Found existing installation: semantic-link-sempy 0.10.2
#     Uninstalling semantic-link-sempy-0.10.2:
#       Successfully uninstalled semantic-link-sempy-0.10.2
# Successfully installed anytree-2.13.0 fabric-analytics-notebook-plugin-0.0.1 fabric-analytics-sdk-0.0.1 jsonpath_ng-1.7.0 polib-1.2.0 semantic-link-labs-0.12.7 semantic-link-sempy-0.12.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import sempy_labs as labs
from sempy_labs import admin
from datetime import datetime, timedelta, timezone
import json
from importlib.metadata import version

# Configure pandas to display all columns for better visibility
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# Retrieve version using importlib instead of direct attribute access
try:
    lib_version = version("semantic-link-labs")
    print("Setup complete. Library version:", lib_version)
except Exception as e:
    print("Setup complete. (Could not determine version number)")
# Out:
# Setup complete. Library version: 0.12.7

# %% [markdown]
# ## 1. Workspace Inventory & Scanner API
#
# This section retrieves a list of all workspaces in the tenant. It then utilizes the **Scanner API** to fetch deep metadata, including dataset schemas and lineage information.
#
# > **Note:** The `scan_workspaces` API has a limit of 100 workspaces per request. The code below includes logic to handle batching if necessary, though the default example scans a specific subset.
#
# **Reference:** [admin.scan_workspaces](https://semantic-link-labs.readthedocs.io/en/stable/sempy_labs.admin.html#sempy_labs.admin.scan_workspaces)

# %%
# 1. List all workspaces in the tenant
df_workspaces = admin.list_workspaces()

# 2. Extract IDs (IDs are more reliable than names)
# For this demo, we will take the first 50 to ensure quick execution
workspace_ids = df_workspaces['Id'].tolist()[:50] 

print(f"Preparing to scan {len(workspace_ids)} workspaces...")

# 3. Run the Workspace Scan
# dataset_schema=True fetches table/column details
# lineage=True fetches upstream/downstream dependencies
scan_result = admin.scan_workspaces(
    workspace=workspace_ids,
    dataset_schema=True,      
    lineage=True              
)

print("Scan complete.")

# 4. Display the result (it returns a DataFrame or Dictionary depending on version)
if isinstance(scan_result, pd.DataFrame):
    display(scan_result.head())
else:
    print("Scan returned object type:", type(scan_result))
# Out:
# Preparing to scan 34 workspaces...
# Scan complete.
# Scan returned object type: <class 'dict'>

# %%
#Show the json object with all the scan details for the tenant
scan_result
# Out:
# {'workspaces': [{'id': '53062423-690f-4923-8f65-db710c038566',
#    'name': 'Steves_Test_App_workSpace',
#    'type': 'Workspace',
#    'state': 'Active',
#    'isOnDedicatedCapacity': False,
#    'reports': [{'reportType': 'PowerBIReport',
#      'id': '2d9f33d3-9433-41c1-8671-f37888c82ba2',
#      'name': 'AFC_PoCv1.0',
#      'datasetId': '12253996-b2f7-46c7-b49f-09ca87cac84f',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': 'a6ffb722-9543-4ee0-b1fa-cab608e0ab1a',
#      'name': 'Jammers vs Floaty Pants',
#      'datasetId': 'b4a5d199-2c6f-4f8d-9fcb-5e4971254f73',
#      'createdDateTime': '2019-11-06T02:44:58.023',
#      'modifiedDateTime': '2019-11-06T02:44:58.023',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': '4553847c-0f64-4c72-90cb-f9645d8b41e2',
#      'name': 'Cook strait swims',
#      'datasetId': 'ccb62787-c192-4542-b523-a4563d861ed7',
#      'createdDateTime': '2021-03-13T05:46:37.217',
#      'modifiedDateTime': '2021-03-13T05:46:37.217',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': '28376cfd-ccc0-4711-ab9e-c3ac71a24e1c',
#      'name': 'Supermarket_Prices1e',
#      'datasetId': '9f028f18-453c-4726-9b62-96160790d2ce',
#      'createdDateTime': '2021-11-26T08:12:55.973',
#      'modifiedDateTime': '2021-11-26T08:12:55.973',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': '17c54708-c53b-49e7-9c6e-78c629bc275a',
#      'name': 'TestPowerBIReport',
#      'datasetId': '8b0f8618-2f32-476e-aee8-728e7af83496',
#      'createdDateTime': '2021-11-26T23:58:16.613',
#      'modifiedDateTime': '2021-11-26T23:58:16.613',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'tags': []}],
#    'dashboards': [{'id': '000042ad-b8eb-4e65-9bb9-ba608f18f609',
#      'displayName': 'Test_Dashboard',
#      'isReadOnly': False,
#      'tiles': [],
#      'tags': []}],
#    'datasets': [{'id': '12253996-b2f7-46c7-b49f-09ca87cac84f',
#      'name': 'AFC_PoCv1.0',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2018-02-01T00:46:47.06',
#      'contentProviderType': 'Unknown',
#      'datasourceUsages': [{'datasourceInstanceId': '1cbb3f99-9706-4d3d-abec-dfd42ba46f2a'},
#       {'datasourceInstanceId': 'a613667d-3d29-486c-b957-662c5036202a'},
#       {'datasourceInstanceId': 'd0faad50-78e4-43e1-9c4b-556ad1499ea2'}],
#      'tags': []},
#     {'id': 'b4a5d199-2c6f-4f8d-9fcb-5e4971254f73',
#      'name': 'Jammers vs Floaty Pants',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2019-11-06T02:44:57.443',
#      'contentProviderType': 'PbixInImportMode',
#      'tags': []},
#     {'id': 'ccb62787-c192-4542-b523-a4563d861ed7',
#      'name': 'Cook strait swims',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2021-03-13T05:46:35.96',
#      'contentProviderType': 'PbixInImportMode',
#      'datasourceUsages': [{'datasourceInstanceId': '5b7f334a-1fe6-4676-b00b-639a933c82b0'},
#       {'datasourceInstanceId': '1d84009d-6f0d-450e-b11e-fb4b21bc2e07'}],
#      'tags': []},
#     {'id': '9f028f18-453c-4726-9b62-96160790d2ce',
#      'name': 'Supermarket_Prices1e',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2021-11-26T08:12:55.117',
#      'contentProviderType': 'PbixInImportMode',
#      'datasourceUsages': [{'datasourceInstanceId': 'f3247f5c-5052-4aec-90b9-391a8a3a7123'}],
#      'tags': []},
#     {'id': '8b0f8618-2f32-476e-aee8-728e7af83496',
#      'name': 'TestPowerBIReport',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2021-11-26T23:58:15.66',
#      'contentProviderType': 'PbixInImportMode',
#      'datasourceUsages': [{'datasourceInstanceId': 'e1468520-dbfd-4735-aeda-dd01597eb957'}],
#      'tags': []}],
#    'dataflows': [],
#    'datamarts': []},
#   {'id': '988f64ea-14b2-4ad7-a899-ae40974c9139',
#    'name': 'DataflowsTest',
#    'type': 'Workspace',
#    'state': 'Active',
#    'isOnDedicatedCapacity': False,
#    'reports': [{'reportType': 'PowerBIReport',
#      'id': '0aa30e3c-dc51-4886-bee8-ebaa24991878',
#      'name': 'DailySalesDashboard13Azure',
#      'datasetId': '9137e0f9-4063-479a-baff-8566c91302ff',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': 'c8377fa0-211a-4730-aa4e-885441a7af6a',
#      'name': 'DMVConnectionTest',
#      'datasetId': 'e5407049-e8ab-4bdb-b18d-f56c5136e12e',
#      'createdDateTime': '2020-09-03T05:19:39.983',
#      'modifiedDateTime': '2020-09-03T05:20:39.13',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': '12763a45-a0f7-4f44-98db-ca89a389f97d',
#      'name': 'TestMCode',
#      'datasetId': '4ff08f1a-db19-4964-b9dc-e0402d4239b4',
#      'createdDateTime': '2020-12-06T22:59:45.237',
#      'modifiedDateTime': '2020-12-07T00:28:53.087',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': 'cb2a64b3-4ab1-421d-9861-1535122313d8',
#      'name': 'DailySalesDashboardDemo',
#      'datasetId': 'c34241c1-23a7-4914-a42e-9c13a4fe8da2',
#      'createdDateTime': '2020-12-07T00:34:18.31',
#      'modifiedDateTime': '2020-12-07T00:34:18.31',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': '3e120d5a-baa1-4716-a0ca-2e6c7be4d847',
#      'name': 'DataflowDatasource',
#      'datasetId': '43dd7611-cfa3-4d0c-a087-646485066cc6',
#      'createdDateTime': '2020-12-08T22:55:32.77',
#      'modifiedDateTime': '2020-12-08T22:55:32.77',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': '0cd533db-651b-4b04-a325-26f5f3895cdb',
#      'name': 'DataflowDataSourcePBIDec2020',
#      'datasetId': '9f38e218-8c01-40a1-bd41-1f90377bb0c2',
#      'createdDateTime': '2020-12-08T23:09:32.027',
#      'modifiedDateTime': '2020-12-08T23:09:32.027',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': 'c960c977-9dc1-4687-b560-860cb8495be4',
#      'name': 'GatewayAPITest',
#      'datasetId': '1f43eb6d-2d6a-44d8-b96f-c2e8bc4173bc',
#      'createdDateTime': '2020-12-11T00:46:24.32',
#      'modifiedDateTime': '2020-12-11T00:46:24.32',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': '75d23ec9-b68a-4af8-be21-9d4265328b07',
#      'name': 'TestPowerBIReport',
#      'datasetId': '670bbec1-38b8-4c7a-b6f4-e5d49f7aae9a',
#      'createdDateTime': '2021-11-26T23:57:27.083',
#      'modifiedDateTime': '2021-11-26T23:57:27.083',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': '782d60c0-8e39-47df-832e-1f05180d0fdb',
#      'name': 'Cook strait swims2',
#      'datasetId': '8ea53ec8-70cf-48eb-9663-8d1c9fee65b1',
#      'createdDateTime': '2022-03-09T21:24:14.637',
#      'modifiedDateTime': '2022-03-09T21:24:14.637',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'tags': []}],
#    'dashboards': [{'id': '8512ecd9-7b00-4927-9737-d7b58614d320',
#      'displayName': 'DailySalesDashboard13Azure.pbix',
#      'isReadOnly': False,
#      'tiles': [{'id': 'dc69fc6c-b00c-4ad5-ba80-175c2cfb24b9',
#        'title': 'DailySalesDashboard13Azure.pbix',
#        'reportId': '0aa30e3c-dc51-4886-bee8-ebaa24991878',
#        'datasetId': '9137e0f9-4063-479a-baff-8566c91302ff'}],
#      'tags': []}],
#    'datasets': [{'id': '9137e0f9-4063-479a-baff-8566c91302ff',
#      'name': 'DailySalesDashboard13Azure',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2018-01-21T22:47:13.5',
#      'contentProviderType': 'Unknown',
#      'datasourceUsages': [{'datasourceInstanceId': 'e24a0019-72fd-4a1d-b7e5-b62f3c55cd64'}],
#      'tags': []},
#     {'id': 'e5407049-e8ab-4bdb-b18d-f56c5136e12e',
#      'name': 'DMVConnectionTest',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2020-09-03T05:19:39.477',
#      'contentProviderType': 'PbixInImportMode',
#      'tags': []},
#     {'id': '4ff08f1a-db19-4964-b9dc-e0402d4239b4',
#      'name': 'TestMCode',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2020-12-06T22:59:44.347',
#      'contentProviderType': 'PbixInImportMode',
#      'tags': []},
#     {'id': 'c34241c1-23a7-4914-a42e-9c13a4fe8da2',
#      'name': 'DailySalesDashboardDemo',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2020-12-07T00:34:17.397',
#      'contentProviderType': 'PbixInImportMode',
#      'datasourceUsages': [{'datasourceInstanceId': 'e24a0019-72fd-4a1d-b7e5-b62f3c55cd64'}],
#      'tags': []},
#     {'id': '43dd7611-cfa3-4d0c-a087-646485066cc6',
#      'name': 'DataflowDatasource',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2020-12-08T22:55:30.92',
#      'contentProviderType': 'PbixInImportMode',
#      'upstreamDataflows': [{'targetDataflowId': 'fb233f01-743a-4ab3-b263-b5a8789836db',
#        'groupId': '988f64ea-14b2-4ad7-a899-ae40974c9139'}],
#      'tags': []},
#     {'id': '9f38e218-8c01-40a1-bd41-1f90377bb0c2',
#      'name': 'DataflowDataSourcePBIDec2020',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2020-12-08T23:09:30.927',
#      'contentProviderType': 'PbixInImportMode',
#      'upstreamDataflows': [{'targetDataflowId': 'fb233f01-743a-4ab3-b263-b5a8789836db',
#        'groupId': '988f64ea-14b2-4ad7-a899-ae40974c9139'}],
#      'tags': []},
#     {'id': '1f43eb6d-2d6a-44d8-b96f-c2e8bc4173bc',
#      'name': 'GatewayAPITest',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2020-12-11T00:46:23.33',
#      'contentProviderType': 'PbixInImportMode',
#      'tags': []},
#     {'id': '670bbec1-38b8-4c7a-b6f4-e5d49f7aae9a',
#      'name': 'TestPowerBIReport',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2021-11-26T23:57:25.61',
#      'contentProviderType': 'PbixInImportMode',
#      'datasourceUsages': [{'datasourceInstanceId': 'e1468520-dbfd-4735-aeda-dd01597eb957'}],
#      'tags': []},
#     {'id': '8ea53ec8-70cf-48eb-9663-8d1c9fee65b1',
#      'name': 'Cook strait swims2',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2022-03-09T21:24:11.967',
#      'contentProviderType': 'PbixInImportMode',
#      'datasourceUsages': [{'datasourceInstanceId': '5b7f334a-1fe6-4676-b00b-639a933c82b0'},
#       {'datasourceInstanceId': '1d84009d-6f0d-450e-b11e-fb4b21bc2e07'}],
#      'tags': []}],
#    'dataflows': [{'objectId': 'fb233f01-743a-4ab3-b263-b5a8789836db',
#      'name': 'PBIFileAnalysis',
#      'description': '',
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedDateTime': '2020-08-23T02:24:29.217Z',
#      'relations': [],
#      'datasourceUsages': [{'datasourceInstanceId': '630dd747-2fc3-4866-afa9-e97f442d219d'},
#       {'datasourceInstanceId': '1558e988-9ead-47f5-8659-fcc991fd3f82'}],
#      'generation': 1,
#      'tags': []}],
#    'datamarts': []},
#   {'id': 'b30f7b7b-6412-49b4-a864-94908e89d5db',
#    'name': 'Pro Workspace',
#    'type': 'Workspace',
#    'state': 'Active',
#    'isOnDedicatedCapacity': False,
#    'reports': [{'reportType': 'PowerBIReport',
#      'id': '3e1e6268-c82a-446f-86c6-b4dada24eb74',
#      'name': 'Cook strait swims',
#      'datasetId': '5316c04a-88ab-4003-9345-86db5efed327',
#      'createdDateTime': '2021-03-02T03:01:08.487',
#      'modifiedDateTime': '2021-03-02T03:48:07.46',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': '2704422f-79c8-4c71-b824-7b4923a78b2a',
#      'name': 'TestPowerBIReport',
#      'datasetId': '349424db-94b0-4148-b80f-198254b4aa4b',
#      'createdDateTime': '2021-11-11T08:13:30.697',
#      'modifiedDateTime': '2021-11-26T23:57:51.66',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': 'aac44085-813c-4bab-ba57-8d861d84ee20',
#      'name': 'NZXSharePrices',
#      'datasetId': '0b9d26d5-96b6-4644-b3db-8a2457b76a81',
#      'createdDateTime': '2021-12-17T22:19:20.223',
#      'modifiedDateTime': '2021-12-17T22:19:20.223',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': 'da8344d6-1586-46d7-aa0f-e263d7066a96',
#      'name': 'Titanic',
#      'datasetId': 'f68fca6b-17bf-4f8b-97e7-b0810e1a5133',
#      'createdDateTime': '2022-06-13T05:32:52.693',
#      'modifiedDateTime': '2022-06-13T05:32:52.693',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'tags': []}],
#    'dashboards': [],
#    'datasets': [{'id': '5316c04a-88ab-4003-9345-86db5efed327',
#      'name': 'Cook strait swims',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2021-03-02T03:01:07.267',
#      'contentProviderType': 'PbixInImportMode',
#      'datasourceUsages': [{'datasourceInstanceId': '5b7f334a-1fe6-4676-b00b-639a933c82b0'},
#       {'datasourceInstanceId': '1d84009d-6f0d-450e-b11e-fb4b21bc2e07'}],
#      'tags': []},
#     {'id': '349424db-94b0-4148-b80f-198254b4aa4b',
#      'name': 'TestPowerBIReport',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2021-11-11T08:13:29.897',
#      'contentProviderType': 'PbixInImportMode',
#      'datasourceUsages': [{'datasourceInstanceId': 'e1468520-dbfd-4735-aeda-dd01597eb957'}],
#      'tags': []},
#     {'id': '0b9d26d5-96b6-4644-b3db-8a2457b76a81',
#      'name': 'NZXSharePrices',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2021-12-17T22:19:15.573',
#      'contentProviderType': 'PbixInImportMode',
#      'datasourceUsages': [{'datasourceInstanceId': '899b4578-163a-4a36-a37d-41a9ddb50c8c'},
#       {'datasourceInstanceId': '2cbcc1b3-faf5-49c6-b7ad-1054e5eb6332'}],
#      'tags': []},
#     {'id': 'f68fca6b-17bf-4f8b-97e7-b0810e1a5133',
#      'name': 'Titanic',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2022-06-13T05:32:51.797',
#      'contentProviderType': 'PbixInImportMode',
#      'datasourceUsages': [{'datasourceInstanceId': '0db38cba-aa91-45e6-8ac1-ad15df05c5df'}],
#      'tags': []}],
#    'dataflows': [],
#    'datamarts': []},
#   {'id': '3c71f90a-f0eb-4fb0-a83e-1dcc5d490084',
#    'name': 'PersonalWorkspace Steve',
#    'type': 'Personal',
#    'state': 'Active',
#    'isOnDedicatedCapacity': False,
#    'reports': [{'reportType': 'PowerBIReport',
#      'id': '3aa953e0-7468-415a-be94-4989d56c394b',
#      'name': 'Argenta_Demo',
#      'datasetId': 'cb04f1ba-a51b-4993-9df0-9ad6715f4eb6',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': '38f72032-fc0b-41c2-bd25-cb50dab35855',
#      'name': 'Sales & Pipeline',
#      'datasetId': 'd327ec08-0952-477c-b168-a3918d0734d7',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': 'dffead70-534c-46c0-84e2-cdc08c21a123',
#      'name': 'NPS PowerBIv10',
#      'datasetId': '4ce986c2-e323-4e6d-9b93-d051ff913f3a',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': '9bd4bcee-be4f-4453-9e1e-a567a3acd554',
#      'name': 'NPS PowerBIv12',
#      'datasetId': 'fbc29a06-134f-48a2-8c5f-fcfe4830eebc',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': 'a363b41a-26da-445a-bc61-3a96b44a6de9',
#      'name': 'NPS Example Dec 2016',
#      'datasetId': 'ced74989-d927-41f0-81db-33aac50ef529',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': '156c54a0-31a7-499d-8e85-a5e814bb48e8',
#      'name': 'DailySalesDashboard13Azure',
#      'datasetId': 'a40c016b-09e6-4e0e-81bf-5e8f9988aede',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': '3c62a5c0-1c4f-4f81-800c-7ee21df26a9e',
#      'name': 'DailySalesDashboard14Azure',
#      'datasetId': 'e82649cb-bda6-4f26-812e-ac5c41d47503',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': '933bd28f-dfce-4097-a83c-681626ab1807',
#      'name': 'Enterprise_Dashboardv1.1',
#      'datasetId': '27926818-8d74-4504-8885-877aecfec2a4',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': '7402305c-e967-42f6-9547-0ca312484846',
#      'name': 'Test',
#      'datasetId': '27926818-8d74-4504-8885-877aecfec2a4',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': '51b901e6-8f07-414e-bb59-9f0bc95466d9',
#      'name': 'Titanic Visual Analytics',
#      'datasetId': 'f6c72855-5473-48f4-b3a8-a20ddde75db1',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': '7991caa9-5583-4712-8f10-10259e47eebd',
#      'name': 'Report Usage Metrics Report',
#      'datasetId': 'a9f015e3-43e3-4cf9-87bd-464241eece48',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': '40918aee-ef5b-4c2d-a051-3309720aaada',
#      'name': 'AFC_PoCv9',
#      'datasetId': '983cadea-8850-42dc-8106-c3f51d9db3c8',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': 'f2d4308b-8629-41e0-b3fe-5cf1166eca78',
#      'name': 'AFC_PoCv1.0',
#      'datasetId': 'b8727247-3322-4405-ab98-c798a8bc37a5',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': '056494d7-a71d-4cca-951b-6b401f563181',
#      'name': 'AFC_PoCv1.1',
#      'datasetId': '348c473f-fce6-4ca6-8119-884a67aef6e0',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': 'a04e31c1-bbb7-4fd8-82cc-0dc4e5275ac3',
#      'name': 'Titanic Visual Analytics_v2',
#      'datasetId': '0ccc5d54-73eb-4726-a3ae-db66d7bde93c',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': '562fd639-becb-40a0-a908-9b990b867424',
#      'name': 'Kohi Series Time analysis v4pbix',
#      'datasetId': '1b050efe-495f-4271-9ba3-3395e3fdb832',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': '04bd36ba-d998-405d-bb0c-3fe4baf70ff3',
#      'name': 'Jammers vs Floaty Pants',
#      'datasetId': '1538ac1d-2598-475f-95fe-3105d1c60bd8',
#      'createdDateTime': '2019-11-06T00:28:34.24',
#      'modifiedDateTime': '2019-11-06T02:44:08.577',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': '9f196522-c829-40bf-8352-69eafde185d4',
#      'name': 'Regional Sales Sample',
#      'datasetId': 'ad92bdb5-335b-4036-8500-5f40cb4d1801',
#      'createdDateTime': '2024-06-19T10:31:14.38',
#      'modifiedDateTime': '2024-06-19T10:31:14.38',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': '73b656eb-4a64-41c2-9e00-d810138df16e',
#      'name': 'Sales',
#      'datasetId': 'b13a296b-180a-49fa-9daa-080343f48373',
#      'createdDateTime': '2024-06-19T10:38:45.79',
#      'modifiedDateTime': '2024-06-19T10:38:45.79',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': '438d7a5c-6b14-4304-84b1-95ab9fc69636',
#      'name': 'Revenue Opportunities',
#      'datasetId': 'd6fe0c6c-1fa3-49a7-b636-10be99da566b',
#      'createdDateTime': '2024-07-10T08:39:06.42',
#      'modifiedDateTime': '2024-07-10T08:39:06.42',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': '15bf7954-f221-49c8-abab-00494ae3c393',
#      'name': 'Regional Sales Sample',
#      'datasetId': '408e3165-b332-4c0c-b2d3-f1b9150a71ed',
#      'createdDateTime': '2024-07-10T08:40:50.91',
#      'modifiedDateTime': '2024-07-10T08:40:50.91',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': '8d3e38bc-753c-4545-9f90-429dd6d67163',
#      'name': 'Corporate Spend',
#      'datasetId': '4071244e-88ad-4cdc-a244-a28279cd0dd6',
#      'createdDateTime': '2024-07-10T08:41:13.31',
#      'modifiedDateTime': '2024-07-10T08:41:13.31',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': '3eb98c15-0931-4ec7-a6dd-3e83b3b92035',
#      'name': 'Test',
#      'datasetId': 'e58989a8-8f43-4832-89e5-77c0c134c5cb',
#      'createdDateTime': '2025-11-14T03:33:16.7',
#      'modifiedDateTime': '2025-11-14T03:33:16.7',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'datasetWorkspaceId': '652330c1-8178-45c2-87d4-326df21303d5',
#      'tags': []}],
#    'dashboards': [{'id': '56e0363e-760c-4eef-86e6-b77982840fc8',
#      'displayName': 'Sales vs Target variance',
#      'isReadOnly': False,
#      'tiles': [{'id': 'e4f031b7-6b97-407d-9305-eb81acdb9ffa',
#        'title': 'Variance - Sales to Target ($)',
#        'reportId': '38f72032-fc0b-41c2-bd25-cb50dab35855',
#        'datasetId': 'd327ec08-0952-477c-b168-a3918d0734d7'}],
#      'tags': []},
#     {'id': '3d1635d7-33af-4a03-84d0-53c750675432',
#      'displayName': 'Sales & Pipeline Analysis',
#      'isReadOnly': False,
#      'tiles': [{'id': 'd9e215a5-ab3e-446f-9eac-fcbc8e7778e8',
#        'title': 'Sales & Pipeline',
#        'subTitle': 'Sales Dashboard',
#        'reportId': '38f72032-fc0b-41c2-bd25-cb50dab35855',
#        'datasetId': 'd327ec08-0952-477c-b168-a3918d0734d7'}],
#      'tags': []},
#     {'id': 'aacce974-571a-48b5-9286-acc834cf2b9c',
#      'displayName': 'NPS Analysis',
#      'isReadOnly': False,
#      'tiles': [{'id': '5568069c-4ac2-4424-b506-c95018070b7f',
#        'title': 'NPS PowerBIv12',
#        'subTitle': 'Dashboard',
#        'reportId': '9bd4bcee-be4f-4453-9e1e-a567a3acd554',
#        'datasetId': 'fbc29a06-134f-48a2-8c5f-fcfe4830eebc'}],
#      'tags': []},
#     {'id': 'f694e7a2-05af-4e97-9a3b-6d9847a1fa78',
#      'displayName': 'Net Promoter Score',
#      'isReadOnly': False,
#      'tiles': [{'id': '83375673-b4d1-44ec-b9f6-386daaf4be50',
#        'title': 'NPS Example Dec 2016',
#        'subTitle': 'Dashboard',
#        'reportId': 'a363b41a-26da-445a-bc61-3a96b44a6de9',
#        'datasetId': 'ced74989-d927-41f0-81db-33aac50ef529'}],
#      'tags': []},
#     {'id': '64a9ae32-eb40-4104-a037-9d5eccd6add1',
#      'displayName': 'Titanic_Test',
#      'isReadOnly': False,
#      'tiles': [{'id': '9d108293-e218-489f-beb9-3da795eb90b7',
#        'title': 'Titanic Visual Analytics',
#        'subTitle': 'Page 4',
#        'reportId': '51b901e6-8f07-414e-bb59-9f0bc95466d9',
#        'datasetId': 'f6c72855-5473-48f4-b3a8-a20ddde75db1'},
#       {'id': '683e871e-577a-4b90-8ce1-06310f5f98e7',
#        'title': 'Titanic Visual Analytics',
#        'subTitle': 'Age Distribution',
#        'reportId': '51b901e6-8f07-414e-bb59-9f0bc95466d9',
#        'datasetId': 'f6c72855-5473-48f4-b3a8-a20ddde75db1'}],
#      'tags': []},
#     {'id': 'cce80ba2-3766-4c21-b486-9b65a406ed1a',
#      'displayName': 'AFC Dashboard PoC',
#      'isReadOnly': False,
#      'tiles': [{'id': 'c4587ca8-8cca-4033-a65c-b0ae4d1333c3',
#        'title': 'AFC_PoCv1.1',
#        'subTitle': 'Graph_Example',
#        'reportId': '056494d7-a71d-4cca-951b-6b401f563181',
#        'datasetId': '348c473f-fce6-4ca6-8119-884a67aef6e0'}],
#      'tags': []},
#     {'id': '8cf2469e-2b7b-49db-bbd9-f9ba57d357e0',
#      'displayName': 'HaarsTest',
#      'isReadOnly': False,
#      'tiles': [{'id': 'e322e162-a5a0-4c5c-aa5f-c95ca20c1f56',
#        'subTitle': '',
#        'datasetId': '9490cd15-7517-44c0-ba07-c9355c9be77a'}],
#      'tags': []},
#     {'id': '46437f18-abf4-46e8-90f2-2e8ab21b4d3e',
#      'displayName': 'StreamingDummyData',
#      'isReadOnly': False,
#      'tiles': [{'id': 'e0a35ebb-e5b9-4ccb-bd89-491921ddc816',
#        'subTitle': '',
#        'datasetId': '0a1a5a17-fb0b-4857-9470-16d7466e2fd6'},
#       {'id': '6bb12ab8-1f63-463d-85e5-327867c398a4',
#        'subTitle': '',
#        'datasetId': '978efc87-c0e6-4613-8450-c2fe0c20934f'}],
#      'tags': []},
#     {'id': '31d854e1-9bbc-4549-bd14-fe18ff16ce5c',
#      'displayName': 'Simplified Streaming Dataset',
#      'isReadOnly': False,
#      'tiles': [{'id': '23173181-ee6b-4ec6-ad43-d5b43e3d91ff',
#        'title': 'Speed',
#        'subTitle': '',
#        'datasetId': 'eaa1107a-2edb-425c-b9ff-493af73e7fe7'},
#       {'id': '4c8d9e74-51af-455a-a9da-d2524a11940e',
#        'title': 'Linegraph',
#        'subTitle': '',
#        'datasetId': 'eaa1107a-2edb-425c-b9ff-493af73e7fe7'}],
#      'tags': []},
#     {'id': 'a21cf11d-ab10-44da-90db-a29f1f409971',
#      'displayName': 'Haars_cascadev2_Dashboard',
#      'isReadOnly': False,
#      'tiles': [{'id': '2b58ddf5-1df9-4ef3-ac4f-4d26fb8d4300',
#        'title': 'FaceCount',
#        'subTitle': '',
#        'datasetId': '754671e9-54bd-4a59-98e8-26b165606099'},
#       {'id': 'fbd55114-c540-4540-9f2f-4cc67a3cdb15',
#        'title': 'Time Series Face Count',
#        'subTitle': '',
#        'datasetId': '754671e9-54bd-4a59-98e8-26b165606099'}],
#      'tags': []}],
#    'datasets': [{'id': 'cb04f1ba-a51b-4993-9df0-9ad6715f4eb6',
#      'name': 'Argenta',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2016-11-30T20:51:11.563',
#      'contentProviderType': 'Unknown',
#      'tags': []},
#     {'id': 'd327ec08-0952-477c-b168-a3918d0734d7',
#      'name': 'DailySalesDashboard10Azure',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2016-11-30T22:39:22.9',
#      'contentProviderType': 'Unknown',
#      'datasourceUsages': [{'datasourceInstanceId': 'e24a0019-72fd-4a1d-b7e5-b62f3c55cd64'}],
#      'tags': []},
#     {'id': '4ce986c2-e323-4e6d-9b93-d051ff913f3a',
#      'name': 'NPS PowerBIv10',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2016-12-05T02:30:02.797',
#      'contentProviderType': 'Unknown',
#      'datasourceUsages': [{'datasourceInstanceId': '137a7426-c0ab-4643-961a-b1641cec3eb6'}],
#      'tags': []},
#     {'id': 'fbc29a06-134f-48a2-8c5f-fcfe4830eebc',
#      'name': 'NPS PowerBIv12',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2016-12-05T10:15:18.063',
#      'contentProviderType': 'Unknown',
#      'datasourceUsages': [{'datasourceInstanceId': '137a7426-c0ab-4643-961a-b1641cec3eb6'}],
#      'tags': []},
#     {'id': 'ced74989-d927-41f0-81db-33aac50ef529',
#      'name': 'NPS Example Dec 2016',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2016-12-05T20:45:49.627',
#      'contentProviderType': 'Unknown',
#      'datasourceUsages': [{'datasourceInstanceId': '137a7426-c0ab-4643-961a-b1641cec3eb6'}],
#      'tags': []},
#     {'id': 'a40c016b-09e6-4e0e-81bf-5e8f9988aede',
#      'name': 'DailySalesDashboard13Azure',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2016-12-06T22:13:42.337',
#      'contentProviderType': 'Unknown',
#      'datasourceUsages': [{'datasourceInstanceId': 'e24a0019-72fd-4a1d-b7e5-b62f3c55cd64'}],
#      'tags': []},
#     {'id': 'e82649cb-bda6-4f26-812e-ac5c41d47503',
#      'name': 'DailySalesDashboard14Azure',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2016-12-07T21:38:45.08',
#      'contentProviderType': 'Unknown',
#      'datasourceUsages': [{'datasourceInstanceId': 'e24a0019-72fd-4a1d-b7e5-b62f3c55cd64'}],
#      'tags': []},
#     {'id': '27926818-8d74-4504-8885-877aecfec2a4',
#      'name': 'Enterprise_Dashboardv1.1',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2017-08-10T00:04:55.363',
#      'contentProviderType': 'Unknown',
#      'tags': []},
#     {'id': 'f6c72855-5473-48f4-b3a8-a20ddde75db1',
#      'name': 'Titanic Visual Analytics',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2017-11-23T22:00:26.043',
#      'contentProviderType': 'Unknown',
#      'tags': []},
#     {'id': 'a9f015e3-43e3-4cf9-87bd-464241eece48',
#      'name': 'Report Usage Metrics Model',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'directQueryRefreshSchedule': {'frequency': 120,
#       'days': [],
#       'times': [],
#       'localTimeZoneId': 'UTC'},
#      'targetStorageMode': 'Abf',
#      'createdDate': '2018-01-21T21:01:33.353',
#      'contentProviderType': 'UsageMetricsUserReport',
#      'tags': []},
#     {'id': '983cadea-8850-42dc-8106-c3f51d9db3c8',
#      'name': 'AFC_PoCv9',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2018-01-31T01:54:31.873',
#      'contentProviderType': 'Unknown',
#      'datasourceUsages': [{'datasourceInstanceId': '1cbb3f99-9706-4d3d-abec-dfd42ba46f2a'},
#       {'datasourceInstanceId': 'a613667d-3d29-486c-b957-662c5036202a'},
#       {'datasourceInstanceId': 'd0faad50-78e4-43e1-9c4b-556ad1499ea2'}],
#      'tags': []},
#     {'id': 'b8727247-3322-4405-ab98-c798a8bc37a5',
#      'name': 'AFC_PoCv1.0',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2018-02-01T00:44:19.817',
#      'contentProviderType': 'Unknown',
#      'datasourceUsages': [{'datasourceInstanceId': '1cbb3f99-9706-4d3d-abec-dfd42ba46f2a'},
#       {'datasourceInstanceId': 'a613667d-3d29-486c-b957-662c5036202a'},
#       {'datasourceInstanceId': 'd0faad50-78e4-43e1-9c4b-556ad1499ea2'}],
#      'tags': []},
#     {'id': '348c473f-fce6-4ca6-8119-884a67aef6e0',
#      'name': 'AFC_PoCv1.1',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2018-02-01T01:42:11.017',
#      'contentProviderType': 'Unknown',
#      'datasourceUsages': [{'datasourceInstanceId': '1cbb3f99-9706-4d3d-abec-dfd42ba46f2a'},
#       {'datasourceInstanceId': 'a613667d-3d29-486c-b957-662c5036202a'},
#       {'datasourceInstanceId': 'd0faad50-78e4-43e1-9c4b-556ad1499ea2'}],
#      'tags': []},
#     {'id': '0ccc5d54-73eb-4726-a3ae-db66d7bde93c',
#      'name': 'Titanic Visual Analytics_v2',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2018-02-19T09:23:30.737',
#      'contentProviderType': 'Unknown',
#      'tags': []},
#     {'id': '1b050efe-495f-4271-9ba3-3395e3fdb832',
#      'name': 'Kohi Series Time analysis v4pbix',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2018-11-06T10:25:36.247',
#      'contentProviderType': 'PbixInImportMode',
#      'datasourceUsages': [{'datasourceInstanceId': '1ba4bfa3-da7f-4270-940e-c743893cfd5d'},
#       {'datasourceInstanceId': 'e823362c-9ca0-4b85-a0a4-ca1b2a1a95c1'},
#       {'datasourceInstanceId': '517eefa4-31dc-4eff-95a4-9903dab01307'},
#       {'datasourceInstanceId': '8e258080-c150-470f-99c9-a26b37c1c847'},
#       {'datasourceInstanceId': 'f818cddd-7689-4a6c-8850-f9f62d535347'},
#       {'datasourceInstanceId': '134d2ac0-c0f0-413f-988b-9109499561d2'},
#       {'datasourceInstanceId': 'a4b543e9-7435-4151-8478-e666b69e3e33'},
#       {'datasourceInstanceId': '9a620205-4582-4c29-bbfd-affc1f8a382f'},
#       {'datasourceInstanceId': '82a80534-5554-4de1-a120-6195b74b3ba7'},
#       {'datasourceInstanceId': 'd13be74c-e2eb-44bc-a58d-476ca1027ae3'},
#       {'datasourceInstanceId': 'b2ca7c72-8075-4dd7-8abb-5f3c81a1a8ba'},
#       {'datasourceInstanceId': '720af4c7-70be-4272-907d-9e315d183d92'}],
#      'tags': []},
#     {'id': '9490cd15-7517-44c0-ba07-c9355c9be77a',
#      'name': 'HaarsCascadeFace',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2019-02-25T19:19:55.827',
#      'contentProviderType': 'RealTimeInPushMode',
#      'schemaRetrievalError': 'Unsupported request. RealTime dataset are not supported.',
#      'tags': []},
#     {'id': '0a1a5a17-fb0b-4857-9470-16d7466e2fd6',
#      'name': 'DummyDataSet(Loop)',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2019-03-13T03:41:10.103',
#      'contentProviderType': 'RealTimeInPushMode',
#      'schemaRetrievalError': 'Unsupported request. RealTime dataset are not supported.',
#      'tags': []},
#     {'id': '978efc87-c0e6-4613-8450-c2fe0c20934f',
#      'name': 'StreamingDummyData',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2019-03-13T03:43:36.273',
#      'contentProviderType': 'RealTimeInStreamingMode',
#      'schemaRetrievalError': 'Unsupported request. RealTime dataset are not supported.',
#      'tags': []},
#     {'id': 'eaa1107a-2edb-425c-b9ff-493af73e7fe7',
#      'name': 'Simplified Streaming Data',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2019-03-13T04:32:05.317',
#      'contentProviderType': 'RealTimeInPushMode',
#      'schemaRetrievalError': 'Unsupported request. RealTime dataset are not supported.',
#      'tags': []},
#     {'id': '754671e9-54bd-4a59-98e8-26b165606099',
#      'name': 'Haars_Cascadev2',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2019-03-24T06:54:40.807',
#      'contentProviderType': 'RealTimeInPushMode',
#      'schemaRetrievalError': 'Unsupported request. RealTime dataset are not supported.',
#      'tags': []},
#     {'id': '1538ac1d-2598-475f-95fe-3105d1c60bd8',
#      'name': 'Jammers vs Floaty Pants',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2019-11-06T00:28:33.58',
#      'contentProviderType': 'PbixInImportMode',
#      'tags': []},
#     {'id': 'ad92bdb5-335b-4036-8500-5f40cb4d1801',
#      'name': 'Regional Sales Sample',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2024-06-19T10:31:10.583',
#      'contentProviderType': 'PbixInImportMode',
#      'datasourceUsages': [{'datasourceInstanceId': 'e63d7942-e7f0-47d7-bc5c-8eb5f62dac8c'}],
#      'tags': []},
#     {'id': 'b13a296b-180a-49fa-9daa-080343f48373',
#      'name': 'Sales',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2024-06-19T10:38:42.437',
#      'contentProviderType': 'PbixInImportMode',
#      'datasourceUsages': [{'datasourceInstanceId': 'e63d7942-e7f0-47d7-bc5c-8eb5f62dac8c'}],
#      'tags': []},
#     {'id': 'd6fe0c6c-1fa3-49a7-b636-10be99da566b',
#      'name': 'Revenue Opportunities',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2024-07-10T08:39:05.347',
#      'contentProviderType': 'PbixInImportMode',
#      'tags': []},
#     {'id': '408e3165-b332-4c0c-b2d3-f1b9150a71ed',
#      'name': 'Regional Sales Sample',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2024-07-10T08:40:47.54',
#      'contentProviderType': 'PbixInImportMode',
#      'datasourceUsages': [{'datasourceInstanceId': 'e63d7942-e7f0-47d7-bc5c-8eb5f62dac8c'},
#       {'datasourceInstanceId': 'e9167ef2-dce0-4609-84e5-59b0eb6f5669'}],
#      'tags': []},
#     {'id': '4071244e-88ad-4cdc-a244-a28279cd0dd6',
#      'name': 'Corporate Spend',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
# ...
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'extendedProperties': {},
#      'tags': []}],
#    'reports': [{'reportType': 'PowerBIReport',
#      'id': '3de715e6-e58b-4639-9621-40925a0233f5',
#      'name': 'Sales-manual',
#      'datasetId': 'e58989a8-8f43-4832-89e5-77c0c134c5cb',
#      'createdDateTime': '2025-11-14T04:01:14.38',
#      'modifiedDateTime': '2025-11-14T04:01:14.38',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'datasetWorkspaceId': '652330c1-8178-45c2-87d4-326df21303d5',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': '2fe54692-bbfb-4488-b19c-036317cc1e8d',
#      'name': 'Sales',
#      'datasetId': 'fb6164fc-12e0-4a38-b4d5-e195568e4d0a',
#      'createdDateTime': '2025-11-14T04:20:57.62',
#      'modifiedDateTime': '2025-11-14T04:20:57.62',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'tags': []}],
#    'dashboards': [],
#    'datasets': [{'id': 'fb6164fc-12e0-4a38-b4d5-e195568e4d0a',
#      'name': 'Sales_updated',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2025-11-14T04:20:44.993',
#      'contentProviderType': 'PbixInImportMode',
#      'datasourceUsages': [{'datasourceInstanceId': 'e63d7942-e7f0-47d7-bc5c-8eb5f62dac8c'}],
#      'tags': []}],
#    'dataflows': [],
#    'datamarts': []},
#   {'id': '62b4f410-25f6-4fb4-8649-8ea89c056715',
#    'name': 'Best Practice Analyser',
#    'type': 'Workspace',
#    'state': 'Active',
#    'isOnDedicatedCapacity': True,
#    'capacityId': '25A2A1D0-792D-4F41-A981-F62B762F9A23',
#    'defaultDatasetStorageFormat': 'Small',
#    'Lakehouse': [{'id': 'a9ce54c6-0cf2-4c35-8792-a9f8074b960a',
#      'name': 'BPA_LH',
#      'description': None,
#      'state': 'Active',
#      'lastUpdatedDate': '2025-06-14T07:28:04.2692538',
#      'createdDate': '2025-06-14T07:27:48.706707',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'extendedProperties': {'OneLakeTablesPath': 'https://onelake.dfs.fabric.microsoft.com/62b4f410-25f6-4fb4-8649-8ea89c056715/a9ce54c6-0cf2-4c35-8792-a9f8074b960a/Tables',
#       'OneLakeFilesPath': 'https://onelake.dfs.fabric.microsoft.com/62b4f410-25f6-4fb4-8649-8ea89c056715/a9ce54c6-0cf2-4c35-8792-a9f8074b960a/Files',
#       'DwProperties': '{"tdsEndpoint":"hqqxbdltuyouvbsy2g27qpn4y4-cd2liyxwew2e7bsjr2ujyblhcu.datawarehouse.fabric.microsoft.com","id":"23284134-6da9-4931-9f0c-e4d1a5004fcc","provisioningStatus":"Success"}'},
#      'tags': []}],
#    'Notebook': [{'id': '912852f5-205a-4786-bce8-8478db8ad390',
#      'name': 'Best Practice Analyzer Report',
#      'description': 'New notebook',
#      'state': 'Active',
#      'lastUpdatedDate': '2025-09-02T01:06:54.2520995',
#      'createdDate': '2025-06-14T07:25:41.70638',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'relations': [{'dependentOnArtifactId': 'a9ce54c6-0cf2-4c35-8792-a9f8074b960a',
#        'workspaceId': '62b4f410-25f6-4fb4-8649-8ea89c056715',
#        'relationType': 'Datasource',
#        'settingsList': 'None',
#        'usage': 'Datasource'}],
#      'extendedProperties': {},
#      'tags': []},
#     {'id': 'd3fca72f-430d-4986-a075-2b08da89dbf8',
#      'name': 'Report Analysis',
#      'description': 'New notebook',
#      'state': 'Active',
#      'lastUpdatedDate': '2025-09-02T01:03:51.3822197',
#      'createdDate': '2025-06-14T05:25:11.8189671',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'extendedProperties': {},
#      'tags': []}],
#    'reports': [{'reportType': 'PowerBIReport',
#      'id': 'c36f1f85-a3ba-4928-ac0e-9b6b21e77cf8',
#      'name': 'ActivityMonitor',
#      'datasetId': 'bc505a51-df42-4a12-b217-6f9f6c1dd154',
#      'createdDateTime': '2025-06-14T05:33:11.177',
#      'modifiedDateTime': '2025-06-14T05:33:11.177',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': '5cb93bb8-d674-4258-8a1f-c18863702ad2',
#      'name': 'ActivityMonitor_project',
#      'datasetId': 'c8212b9d-f918-437f-bd62-4ce6c60983b6',
#      'createdDateTime': '2025-06-14T05:41:10.863',
#      'modifiedDateTime': '2025-06-14T07:19:26',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'tags': []},
#     {'reportType': 'PowerBIReport',
#      'id': 'c62cc6e9-2ede-403a-9756-1f96412c368b',
#      'name': 'ModelBPA',
#      'datasetId': '64538b0d-7b6b-4336-a817-1ea2c51820fb',
#      'createdDateTime': '2025-06-14T07:39:10.117',
#      'modifiedDateTime': '2025-06-14T07:39:10.117',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'tags': []}],
#    'dashboards': [],
#    'datasets': [{'id': 'bc505a51-df42-4a12-b217-6f9f6c1dd154',
#      'name': 'ActivityMonitor',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2025-06-14T05:33:09.813',
#      'contentProviderType': 'PbixInImportMode',
#      'datasourceUsages': [{'datasourceInstanceId': 'acbd6b71-9a69-420c-b7ac-500b26dcbdeb'}],
#      'tags': []},
#     {'id': 'c8212b9d-f918-437f-bd62-4ce6c60983b6',
#      'name': 'ActivityMonitor_project',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2025-06-14T05:41:09.48',
#      'contentProviderType': 'PbixInImportMode',
#      'datasourceUsages': [{'datasourceInstanceId': 'acbd6b71-9a69-420c-b7ac-500b26dcbdeb'}],
#      'tags': []},
#     {'id': 'a6a28d9f-8aa6-4eca-91b8-3e730ec9842e',
#      'name': 'BPA_LH',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2025-06-14T07:27:52.543',
#      'contentProviderType': 'InImportMode',
#      'tags': []},
#     {'id': '64538b0d-7b6b-4336-a817-1ea2c51820fb',
#      'name': 'ModelBPA',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2025-06-14T07:38:34.91',
#      'contentProviderType': 'PbixInCompositeMode',
#      'relations': [{'dependentOnArtifactId': '23284134-6da9-4931-9f0c-e4d1a5004fcc',
#        'workspaceId': '62b4f410-25f6-4fb4-8649-8ea89c056715',
#        'relationType': 'Association',
#        'settingsList': 'Association',
#        'usage': 'None'}],
#      'tags': []}],
#    'dataflows': [],
#    'datamarts': [],
#    'SQLAnalyticsEndpoint': [{'id': '23284134-6da9-4931-9f0c-e4d1a5004fcc',
#      'name': 'BPA_LH',
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'modifiedDateTime': '2025-06-14T07:28:07.4880088',
#      'tags': [],
#      'relations': [{'dependentOnArtifactId': 'a9ce54c6-0cf2-4c35-8792-a9f8074b960a',
#        'workspaceId': '62b4f410-25f6-4fb4-8649-8ea89c056715',
#        'relationType': 'CascadeDelete',
#        'settingsList': 'CascadeDelete',
#        'usage': 'None'}]}]},
#   {'id': 'a2caaaf0-b9a4-4c22-b955-bae633ba9673',
#    'name': 'DoC -Scanner and Activity Events Test',
#    'description': 'Working scanner API',
#    'type': 'Workspace',
#    'state': 'Active',
#    'isOnDedicatedCapacity': True,
#    'capacityId': '25A2A1D0-792D-4F41-A981-F62B762F9A23',
#    'defaultDatasetStorageFormat': 'Small',
#    'Notebook': [{'id': '9d8acfb9-087d-419e-bd15-9884ea2edb7a',
#      'name': 'Activity Events',
#      'description': 'New notebook',
#      'state': 'Active',
#      'lastUpdatedDate': '2025-07-24T01:17:10.0652841',
#      'createdDate': '2025-07-04T09:45:43.4125438',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'extendedProperties': {},
#      'tags': []},
#     {'id': 'ec7fb8c9-6ac9-48e4-8921-6d556d9496cb',
#      'name': 'Graph API',
#      'description': 'New notebook',
#      'state': 'Active',
#      'lastUpdatedDate': '2025-10-29T01:42:51.641409',
#      'createdDate': '2025-07-04T22:17:09.7238821',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'extendedProperties': {},
#      'tags': []},
#     {'id': '6071ea76-1bd7-44bb-9603-be7833feb743',
#      'name': 'MCP activity search',
#      'description': 'New notebook',
#      'state': 'Active',
#      'lastUpdatedDate': '2025-07-16T20:33:24.1539876',
#      'createdDate': '2025-07-07T18:31:23.520029',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'extendedProperties': {},
#      'tags': []},
#     {'id': '8dd5bfc3-1099-4352-86f9-e676241c49ed',
#      'name': 'Notebook 1',
#      'description': 'New notebook',
#      'state': 'Active',
#      'lastUpdatedDate': '2025-07-24T01:31:47.5652189',
#      'createdDate': '2025-07-24T01:29:19.1251333',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'extendedProperties': {},
#      'tags': []},
#     {'id': 'bbe0ac54-7d69-4ad2-911e-dfaf7b14b22f',
#      'name': 'Scanner API ',
#      'description': 'New notebook',
#      'state': 'Active',
#      'lastUpdatedDate': '2025-07-24T01:27:06.8103137',
#      'createdDate': '2025-07-04T08:15:14.8900667',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'extendedProperties': {},
#      'tags': []},
#     {'id': 'ea0aab2b-5afe-44a7-b42b-9f462333d0cf',
#      'name': 'Tenant Settings',
#      'description': 'New notebook',
#      'state': 'Active',
#      'lastUpdatedDate': '2025-07-22T10:20:01.2031972',
#      'createdDate': '2025-07-04T22:19:33.4278812',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'extendedProperties': {},
#      'tags': []}],
#    'reports': [],
#    'dashboards': [],
#    'datasets': [],
#    'dataflows': [],
#    'datamarts': []},
#   {'id': '76199f5a-1ec6-4dd7-9751-0e79c93d5319',
#    'name': 'Difinity Code',
#    'type': 'Workspace',
#    'state': 'Active',
#    'isOnDedicatedCapacity': True,
#    'capacityId': '25A2A1D0-792D-4F41-A981-F62B762F9A23',
#    'defaultDatasetStorageFormat': 'Small',
#    'Notebook': [{'id': '9104eeac-1cc1-4b73-9bea-8f5d2ec5d191',
#      'name': 'Difinity Code',
#      'description': None,
#      'state': 'Active',
#      'lastUpdatedDate': '2025-11-20T09:00:10.316737',
#      'createdDate': '2025-10-28T22:05:04.3107726',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'extendedProperties': {},
#      'tags': []},
#     {'id': 'cbdca5b7-f57e-45d1-8602-c6f4e1386eff',
#      'name': 'Folders_test',
#      'description': None,
#      'state': 'Active',
#      'lastUpdatedDate': '2025-11-14T01:41:24.7356795',
#      'createdDate': '2025-11-14T01:41:05.5745001',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'extendedProperties': {},
#      'tags': []}],
#    'reports': [{'reportType': 'PowerBIReport',
#      'id': '73d20017-cc62-4772-bbcb-67e0d1ce0188',
#      'name': 'PubtoWeb',
#      'datasetId': '8efedec8-7f46-4616-bab0-04beb7cef849',
#      'createdDateTime': '2025-11-14T01:39:38.317',
#      'modifiedDateTime': '2025-11-14T01:39:38.317',
#      'modifiedBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'createdBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'modifiedById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'createdById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'tags': []}],
#    'dashboards': [],
#    'datasets': [{'id': '8efedec8-7f46-4616-bab0-04beb7cef849',
#      'name': 'PubtoWeb',
#      'tables': [],
#      'configuredBy': 'Analytics@InsightServicesLtd.onmicrosoft.com',
#      'configuredById': 'e4be8e49-1efa-42c1-8c5c-2689d0c5aac4',
#      'isEffectiveIdentityRequired': False,
#      'isEffectiveIdentityRolesRequired': False,
#      'targetStorageMode': 'Abf',
#      'createdDate': '2025-11-14T01:39:37.153',
#      'contentProviderType': 'PbixInImportMode',
#      'tags': []}],
#    'dataflows': [],
#    'datamarts': []},
#   {'id': 'e8bbe11e-4e3b-483e-9955-0cb59c118411',
#    'name': 'Human Resources',
#    'type': 'Workspace',
#    'state': 'Active',
#    'isOnDedicatedCapacity': True,
#    'capacityId': '25A2A1D0-792D-4F41-A981-F62B762F9A23',
#    'defaultDatasetStorageFormat': 'Small',
#    'reports': [],
#    'dashboards': [],
#    'datasets': [],
#    'dataflows': [],
#    'datamarts': []}]}

# %% [markdown]
# ## 2. Workspace Security & Access
#
# Understanding who has access to your data is critical. This function retrieves the **Role Assignments** (Admin, Member, Contributor, Viewer) for a specific workspace.
#
# **Reference:** [labs.list_workspace_role_assignments](https://semantic-link-labs.readthedocs.io/en/stable/sempy_labs.html#sempy_labs.list_workspace_role_assignments)

# %%
# Replace with a valid Workspace ID or Name from your tenant
target_workspace = "Sales" 

try:
    roles_df = labs.list_workspace_role_assignments(workspace=target_workspace)
    display(roles_df)
except Exception as e:
    print(f"Error accessing workspace '{target_workspace}': {e}")

# %% [markdown]
# ## 3. Tenant Auditing: Activity Events
#
# This section fetches the **Activity Events** (Audit Logs) for the tenant. This is useful for identifying who accessed what report, or what API operations were performed.
#
# > **Note:** The API requires start and end times in UTC. This script defaults to "Yesterday (UTC)".
#
# **Reference:** [admin.list_activity_events](https://semantic-link-labs.readthedocs.io/en/stable/sempy_labs.admin.html#sempy_labs.admin.list_activity_events)

# %%
# Calculate UTC time range for yesterday
utc_now = datetime.now(timezone.utc)
yesterday = (utc_now - timedelta(days=1)).date()

start_str = f"{yesterday.strftime('%Y-%m-%d')}T00:00:00"
end_str   = f"{yesterday.strftime('%Y-%m-%d')}T23:59:59"

print(f"Fetching events for: {start_str} to {end_str} (UTC)")

# Fetch events
events_df = admin.list_activity_events(start_time=start_str, end_time=end_str)

# Normalize JSON data if necessary
if not isinstance(events_df, pd.DataFrame):
    events_df = pd.json_normalize(events_df)

print(f"Fetched {len(events_df):,} events.")
display(events_df.head(5))
# Out:
# Fetching events for: 2025-11-19T00:00:00 to 2025-11-19T23:59:59 (UTC)
# Fetched 4 events.

# %% [markdown]
# ## 4. Cleanup: Identify Unused Artifacts
#
# This function scans a workspace to identify artifacts (Reports, Datasets, Dashboards) that have not been accessed recently. This is essential for tenant hygiene and cost management.
#
# **Reference:** [admin.list_unused_artifacts](https://semantic-link-labs.readthedocs.io/en/stable/sempy_labs.admin.html#sempy_labs.admin.list_unused_artifacts)

# %%
target_workspace_cleanup = "Sales" # Replace with your workspace name

try:
    # Returns artifacts not accessed in the last 30 days (default)
    unused_df = admin.list_unused_artifacts(workspace=target_workspace_cleanup)
    
    if not unused_df.empty:
        print("Found the following unused artifacts:")
        display(unused_df)
    else:
        print("No unused artifacts found.")
        
except Exception as e:
    print(f"Could not scan workspace: {e}")
# Out:
# No unused artifacts found.

# %% [markdown]
# ## 5. Tenant Settings: Manage Preview Features
#
# This script discovers all Tenant Settings that are currently in **Preview** and are **Enabled**. It demonstrates how to programmatically list settings.
#
# > **Warning:** The code to *disable* settings is included but commented out for safety. Updating tenant settings affects all users immediately.
#
# **Reference:** [admin.list_tenant_settings](https://semantic-link-labs.readthedocs.io/en/stable/sempy_labs.admin.html#sempy_labs.admin.list_tenant_settings)

# %%
import sempy.fabric as fabric

# 1. Get all tenant settings
settings_df = admin.list_tenant_settings()

# 2. Filter for 'Enabled' features that contain '(preview)' in the title
preview_enabled = settings_df[
    (settings_df['Title'].str.contains(r'\(preview\)', case=False, na=False)) & 
    (settings_df['Enabled'] == True)
]

print(f"Found {len(preview_enabled)} enabled preview features.")
display(preview_enabled[['Setting Name', 'Title', 'Enabled']])

# 3. (Optional) Bulk Disable Logic
# client = fabric.FabricRestClient()
# for index, row in preview_enabled.iterrows():
#     setting_name = row['Setting Name']
#     try:
#         print(f"Disabling: {setting_name}")
#         # client.post(f"/v1/admin/tenantsettings/{setting_name}/update", 
#         #             json={"enabled": False, "enabledSecurityGroups": []})
#     except Exception as e:
#         print(f"Failed to update {setting_name}: {e}")
# Out:
# Found 21 enabled preview features.

# %% [markdown]
# ## 6. Optimization: Best Practice Analyzer (BPA)
#
# The BPA scans Semantic Models within a workspace against a set of standard rules (performance, formatting, DAX expressions) to ensure model quality.
#
# An lakehouse is required and acts as the destination for the BPA results
#
# **Reference:** [labs.run_model_bpa_bulk](https://semantic-link-labs.readthedocs.io/en/stable/sempy_labs.html#sempy_labs.run_model_bpa_bulk)

# %%
target_workspace_bpa = "Sales"

print(f"Running BPA on: {target_workspace_bpa}")

try:
    bpa_results = labs.run_model_bpa_bulk(workspace=target_workspace_bpa)
    display(bpa_results)
except Exception as e:
    print(f"BPA Run failed: {e}")
# Out:
# Running BPA on: Sales
# ⌛ Collecting Model BPA stats for the 'Sales' semantic model within the 'Sales' workspace.
# 🟢 Collected Model BPA stats for the 'Sales' semantic model within the 'Sales' workspace.
# ⌛ Collecting Model BPA stats for the 'Table Filter' semantic model within the 'Sales' workspace.
# 🟢 Collected Model BPA stats for the 'Table Filter' semantic model within the 'Sales' workspace.
# ⌛ Collecting Model BPA stats for the 'Column Filter' semantic model within the 'Sales' workspace.
# 🟢 Collected Model BPA stats for the 'Column Filter' semantic model within the 'Sales' workspace.
# ⌛ Collecting Model BPA stats for the 'Top candidates (S1 & S2 logic)' semantic model within the 'Sales' workspace.
# 🟢 Collected Model BPA stats for the 'Top candidates (S1 & S2 logic)' semantic model within the 'Sales' workspace.
# ⌛ Collecting Model BPA stats for the 'Outbound email targeting' semantic model within the 'Sales' workspace.
# 🟢 Collected Model BPA stats for the 'Outbound email targeting' semantic model within the 'Sales' workspace.
# ⌛ Saving the Model BPA results of the 'Sales' workspace to the 'modelbparesults' within the lakehouse attached to this notebook...
# 🟢 The dataframe has been saved as the 'modelbparesults' table in the 'BPA' lakehouse within the 'Difinity Code' workspace.
# 🟢 Saved BPA results to the 'modelbparesults' delta table.
# 🟢 Bulk BPA scan complete.

# %%
from deltalake import DeltaTable, write_deltalake
table_path = 'abfss://76199f5a-1ec6-4dd7-9751-0e79c93d5319@onelake.dfs.fabric.microsoft.com/ce5ef1f1-6e19-416e-9c74-d48fff22f1ee/Tables/modelbparesults' 
storage_options = {"bearer_token": notebookutils.credentials.getToken('storage'), "use_fabric_endpoint": "true"}
dt = DeltaTable(table_path, storage_options=storage_options)
limited_data = dt.to_pyarrow_dataset().head(1000).to_pandas()
display(limited_data)

# Write data frame to Lakehouse
# write_deltalake(table_path, limited_data, mode='overwrite')

# If the table is too large and might cause an Out of Memory (OOM) error,
# you can try using the code below. However, please note that delta_scan with default lakehouse is currently in preview.
# import duckdb
# display(duckdb.sql("select * from delta_scan('/lakehouse/default/Tables/dbo/bigdeltatable') limit 1000 ").df())

# %% [markdown]
# ## 7. Strategy Check: Apps vs. Workspaces
#
# This script analyzes the Activity Events (fetched in Block 4) to calculate the **"App Adoption Rate"**. It checks how many report views came through an App versus directly through the Workspace.
#
# **Reference:** [admin.list_apps](https://semantic-link-labs.readthedocs.io/en/stable/sempy_labs.admin.html#sempy_labs.admin.list_apps)

# %%
# Ensure you have run Block 4 (Activity Events) first to get 'events_df'

print("Analyzing Report Consumption Methods...")

# 1. Filter for "ViewReport" operations only
view_events = events_df[events_df['Operation'] == 'ViewReport'].copy()

# 2. Determine if the view was via an App
# Note: The field name in audit logs can vary, but 'AppId' is usually present if viewed via App
if 'AppId' in view_events.columns:
    view_events['IsAppView'] = view_events['AppId'].notna() & (view_events['AppId'] != '')
else:
    # Fallback logic if AppId column is missing in the raw feed
    view_events['IsAppView'] = False 

# 3. Calculate Stats
total_views = len(view_events)
app_views = len(view_events[view_events['IsAppView'] == True])
workspace_views = len(view_events[view_events['IsAppView'] == False])

if total_views > 0:
    adoption_rate = (app_views / total_views) * 100
    print(f"Total Report Views: {total_views}")
    print(f"✅ Views via App:     {app_views} ({adoption_rate:.1f}%)")
    print(f"❌ Views via Workspace: {workspace_views} ({100 - adoption_rate:.1f}%)")
    
    if adoption_rate < 50:
        print("\n⚠️ Insight: The majority of users are accessing reports directly in Workspaces. Review 'Workspace Viewer' roles.")
else:
    print("No 'ViewReport' events found in the selected time range.")

# 4. (Optional) List all Apps in the Tenant for Inventory
# apps_df = admin.list_apps()
# display(apps_df.head())
# Out:
# Analyzing Report Consumption Methods...
# Total Report Views: 2
# ✅ Views via App:     0 (0.0%)
# ❌ Views via Workspace: 2 (100.0%)
#
# ⚠️ Insight: The majority of users are accessing reports directly in Workspaces. Review 'Workspace Viewer' roles.
